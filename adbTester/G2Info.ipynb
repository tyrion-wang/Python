# %%
import os
import sys
import time
import GPU_Info
import CPU_Info
import myPrint

if __name__=='__main__':
    while 1:
        info = {}
        info.update(GPU_Info.getBusy())
        info["=============CPU温度"]="============="
        info.update(CPU_Info.getTemp())
                    
        os.system('clear')
        for key in info:
            print(key+":"+info[key])

        time.sleep(0.5)
# Out:
# GPU占用率:96.5%
# GPU频率:596000000
# =============CPU温度:=============
# battery:32.0
# pm8998_tz:72.2
# tsens_tz_sensor3:85.8
# tsens_tz_sensor4:86.4
# tsens_tz_sensor7:85.8
# tsens_tz_sensor8:85.1
# tsens_tz_sensor9:85.8
# tsens_tz_sensor10:91.2
# tsens_tz_sensor11:83.5
# tsens_tz_sensor12:89.9
# tsens_tz_sensor13:88.7
# tsens_tz_sensor14:80.3
# pmi8998_tz:37.0
# tsens_tz_sensor15:83.2
# tsens_tz_sensor16:82.5
# tsens_tz_sensor17:82.5
# tsens_tz_sensor18:81.6
# tsens_tz_sensor19:82.9
# tsens_tz_sensor20:79.3
# tsens_tz_sensor21:81.6
# bms:32.0
# pm8005_tz:37.0
# GLM_soc:0.0
# LLM_cp1-:0.0
# LLM_cp0-:0.0
# msm_therm:73.0
# quiet_therm:68.0
# xo_therm:-39.0
# tsens_tz_sensor0:80.3
# tsens_tz_sensor1:86.7
# tsens_tz_sensor2:86.4
# GPU占用率:95.5%
# GPU频率:670000000
# =============CPU温度:=============
# battery:32.0
# pm8998_tz:72.1
# tsens_tz_sensor3:86.4
# tsens_tz_sensor4:86.7
# tsens_tz_sensor7:84.8
# tsens_tz_sensor8:82.9
# tsens_tz_sensor9:85.4
# tsens_tz_sensor10:91.5
# ...
