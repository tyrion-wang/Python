# %%
#-*- coding: UTF-8 -*-

import sys
import time
import urllib3
import certifi
import requests
import numpy as np
from bs4 import BeautifulSoup
from openpyxl import Workbook

# %%
#reload(sys)
#sys.setdefaultencoding('utf8')

# %%
#Some User Agents
hds=[{'User-Agent':'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'},\
{'User-Agent':'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.12 Safari/535.11'},\
{'User-Agent': 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/6.0)'}]

# %%
def get_hot_movie():
    page_num=0;
    data_type=['片名','主演','导演','豆瓣评分','时长','上映地区']
    movie_list=[]
    try_times=0
    
    #print "电影开始book_spider"+book_tag
    #url='https://www.douban.com/tag/'+urllib.quote(book_tag)+'/book?start='+str(page_num*15)
    #url='https://www.douban.com'
    #url='https://movie.douban.com/tag/#/?sort=U&range=0,10&tags='+book_tag
    url='https://movie.douban.com'
    time.sleep(np.random.rand()*5)
    try:  
        http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())  # 创建请求
        ret = http.request('GET', url)  # 返回一个 HTTPResponse 对象
        #print(ret.status)  # 返回状态 200/404/...
        #print(ret.data.decode('utf-8')) 
        plain_text = ret.data.decode('utf-8')
        #print plain_text
    except (urllib3.exceptions.HTTPError) as e:
        print("OS error: {0}".format(e))
        
    soup = BeautifulSoup(plain_text)
    list_soup = soup.find('div', {'class': 'screening-bd'})
    #print list_soup
    
    for movie_info in list_soup.findAll('li',{'class':'ui-slide-item'}):
        try:
            title = movie_info.get('data-title')
            actors = movie_info.get('data-actors')
            director = movie_info.get('data-director')
            rate = movie_info.get('data-rate')
            duration = movie_info.get('data-duration')
            region = movie_info.get('data-region')
            
            print ("片名："+title)
            print ("主演："+actors)
            print ("导演："+director)
            print ("豆瓣评分："+rate)
            print ("时长："+duration)
            print ("上映地区："+region)
            print ("===================================================")
            movie_list.append([title,actors,director,rate,duration,region])
        except TypeError:
            print ("这个位置没有海报")
            print ("===================================================")
    
    return movie_list,data_type

# %%
def print_lists_to_excel(movie_lists,data_types):
    #for movie in movie_lists:
    #    print movie[0]
    
    #for atype in data_type:
    #    print atype
    
    wb=Workbook()
    ws=wb.active
    ws.title = '热映片单'
    #ws['A1'] = data_type[0] 
    for i in range(len(data_types)):
        ws.cell(row=1, column=i+1, value=data_types[i])
        for j in range(len(movie_lists)):
            ws.cell(row=j+2, column=i+1, value=movie_lists[j][i])
        
    wb.save('热映片单.xlsx')

# %%
if __name__=='__main__':
    movie_lists,data_types=get_hot_movie()
    print_lists_to_excel(movie_lists,data_types)
# Out:
# 片名：死侍2：我爱我家 Deadpool 2
# 主演：瑞恩·雷诺兹 / 乔什·布洛林 / 朱利安·迪尼森
# 导演：大卫·雷奇
# 豆瓣评分：7.4
# 时长：119分钟
# 上映地区：美国
# ===================================================
# 片名：密室逃生 Escape Room
# 主演：泰勒·拉塞尔 / 洛根·米勒 / 黛博拉·安沃尔
# 导演：亚当·罗比特尔
# 豆瓣评分：7.3
# 时长：100分钟
# 上映地区：美国
# ===================================================
# 片名：白蛇：缘起
# 主演：张喆 / 杨天翔 / 唐小喜
# 导演：黄家康
# 豆瓣评分：8.0
# 时长：99分钟
# 上映地区：中国大陆
# ===================================================
# 片名：大黄蜂 Bumblebee
# 主演：海莉·斯坦菲尔德 / 小豪尔赫·兰登伯格 / 约翰·塞纳
# 导演：特拉维斯·奈特
# 豆瓣评分：7.1
# 时长：114分钟
# 上映地区：美国
# ===================================================
# 片名：“大”人物
# 主演：王千源 / 包贝尔 / 王迅
# 导演：五百
# 豆瓣评分：6.7
# 时长：107分钟
# 上映地区：中国大陆
# ===================================================
# 片名：大侦探霍桑
# 主演：韩庚 / 尹正 / 张慧雯
# 导演：周显扬
# 豆瓣评分：3.5
# 时长：98分钟
# 上映地区：中国大陆
# ===================================================
# 片名：战斗民族养成记
# 主演：董畅 / 伊丽莎维塔·科诺诺娃 / 维塔利·哈耶夫
# 导演：列索·科克涅什维利
# 豆瓣评分：4.8
# 时长：93分钟
# 上映地区：中国大陆
# ===================================================
# 片名：一条狗的回家路 A Dog's Way Home
# 主演：艾什莉·贾德 / 乔纳·豪尔-金 / 亚历山德拉·希普
# 导演：查尔斯·马丁·史密斯
# 豆瓣评分：6.8
# 时长：96分钟
# 上映地区：美国
# ===================================================
# 片名：掠食城市 Mortal Engines
# 主演：海拉·西尔玛 / 雨果·维文 / 金吉
# 导演：克里斯蒂安·瑞沃斯
# 豆瓣评分：6.7
# 时长：128分钟
# 上映地区：美国
# ===================================================
# 片名：海王 Aquaman
# 主演：杰森·莫玛 / 艾梅柏·希尔德 / 威廉·达福
# 导演：温子仁
# 豆瓣评分：7.8
# 时长：143分钟
# 上映地区：美国
# ===================================================
# 片名：钢铁飞龙之奥特曼崛起
# 主演：
# 导演：王巍
# 豆瓣评分：3.2
# 时长：90分钟
# 上映地区：中国大陆
# ===================================================
# 片名：来电狂响
# 主演：佟大为 / 马丽 / 霍思燕
# 导演：于淼
# 豆瓣评分：6.0
# 时长：103分钟
# 上映地区：中国大陆
# ===================================================
# 片名：森林奇缘 Викрадена принцеса: Руслан i Людмила
# 主演：Nadezhda / Aleksey / Yevhen
# 导演：Oleh
# 豆瓣评分：
# 时长：91分钟
# 上映地区：乌克兰
# ===================================================
# 片名：蜘蛛侠：平行宇宙 Spider-Man: Into the Spider-Verse
# 主演：沙梅克·摩尔 / 杰克·约翰逊 / 海莉·斯坦菲尔德
# 导演：鲍勃·佩尔西凯蒂
# 豆瓣评分：8.8
# 时长：116分钟(中国大陆)
# 上映地区：美国
# ===================================================
# 片名：我想吃掉你的胰脏 君の膵臓をたべたい
# 主演：高杉真宙 / Lynn / 藤井雪代
# 导演：牛岛新一郎
# 豆瓣评分：6.8
# 时长：108分钟
# 上映地区：日本
# ===================================================
# 片名：燃点
# 主演：罗永浩 / 戴威 / 张颖
# 导演：关琇
# 豆瓣评分：6.0
# 时长：107分钟
# 上映地区：中国大陆
# ===================================================
# 片名：四个春天
# 主演：陆运坤 / 李桂贤
# 导演：陆庆屹
# 豆瓣评分：8.9
# 时长：105分钟
# 上映地区：中国大陆
# ===================================================
# 片名：闯堂兔3囧囧时光机
# 主演：
# 导演：曾宪林
# 豆瓣评分：
# 时长：88分钟
# 上映地区：中国大陆
# ===================================================
# 片名：德鲁大叔 Uncle Drew
# 主演：凯里·欧文 / 里尔·莱尔·哈瓦瑞 / 沙奎尔·奥尼尔
# 导演：查尔斯·斯通三世
# 豆瓣评分：6.5
# 时长：103分钟
# 上映地区：美国
# ===================================================
# 片名：命运之夜——天之杯：恶兆之花 劇場版「Fate/stay night」Heaven's Feel - I. presage flower
# 主演：杉山纪彰 / 下屋则子 / 神谷浩史
# 导演：须藤友德
# 豆瓣评分：7.6
# 时长：119分钟(中国大陆)
# 上映地区：日本
# ===================================================
# 片名：养家之人 The Breadwinner
# 主演：莎拉·乔德利 / 索玛·查亚 / 诺林·古拉姆高斯
# 导演：诺拉·托梅
# 豆瓣评分：8.3
# 时长：94分钟
# 上映地区：爱尔兰
# ===================================================
# 片名：龙猫 となりのトトロ
# 主演：日高法子 / 坂本千夏 / 糸井重里
# 导演：宫崎骏
# 豆瓣评分：9.2
# 时长：86分钟
# 上映地区：日本
# ===================================================
# 片名：家和万事惊 家和萬事驚
# 主演：吴镇宇 / 古天乐 / 袁咏仪
# 导演：邱礼涛
# 豆瓣评分：6.4
# 时长：92分钟
# 上映地区：中国大陆
# ===================================================
# 片名：熊出没·原始时代
# 主演：张伟 / 张秉君 / 谭笑
# 导演：丁亮
# 豆瓣评分：
# 时长：88分钟
# 上映地区：中国大陆
# ===================================================
# 片名：云南虫谷
# 主演：蔡珩 / 顾璇 / 于恒
# 导演：非行
# 豆瓣评分：3.5
# 时长：110分钟
# 上映地区：中国大陆
# ===================================================
# 片名：杨门女将之女将初征
# 主演：陆韵涵 / 程硙山 / 李睿君
# 导演：李文浩
# 豆瓣评分：
# 时长：98分钟
# 上映地区：中国大陆
# ===================================================
# 片名：地球最后的夜晚
# 主演：汤唯 / 黄觉 / 张艾嘉
# 导演：毕赣
# 豆瓣评分：7.0
# 时长：140分钟
# 上映地区：中国大陆
# ===================================================
# 片名：22年后的自白 22年目の告白 私が殺人犯です
# 主演：藤原龙也 / 伊藤英明 / 夏帆
# 导演：入江悠
# 豆瓣评分：7.2
# 时长：110分钟(中国大陆)
# 上映地区：日本
# ===================================================
# 片名：断片之险途夺宝
# 主演：葛优 / 岳云鹏 / 杜淳
# 导演：罗登
# 豆瓣评分：2.6
# 时长：95分钟
# 上映地区：中国大陆
# ===================================================
# 片名：心迷宫
# 主演：霍卫民 / 王笑天 / 罗芸
# 导演：忻钰坤
# 豆瓣评分：8.7
# 时长：110分钟(中国大陆)
# 上映地区：中国大陆
# ===================================================
# 片名：生活万岁
# 主演：
# 导演：程工
# 豆瓣评分：7.4
# 时长：94分钟
# 上映地区：中国大陆
# ===================================================
# 片名：奎迪：英雄再起 Creed II
# 主演：迈克尔·B·乔丹 / 西尔维斯特·史泰龙 / 泰莎·汤普森
# 导演：小斯蒂芬·卡普尔
# 豆瓣评分：7.4
# 时长：130分钟
# 上映地区：美国
# ===================================================
# 片名：中国合伙人2
# 主演：赵立新 / 凌潇肃 / 王嘉
# 导演：刘亚当
# 豆瓣评分：4.2
# 时长：123分钟
# 上映地区：中国大陆
# ===================================================
# 片名：疯狂的外星人
# 主演：黄渤 / 沈腾 / 马修·莫里森
# 导演：宁浩
# 豆瓣评分：
# 时长：116分钟
# 上映地区：中国大陆
# ===================================================
# 片名：神探蒲松龄
# 主演：成龙 / 阮经天 / 钟楚曦
# 导演：严嘉
# 豆瓣评分：
# 时长：
# 上映地区：中国大陆
# ===================================================
# 片名：自行车与旧电钢
# 主演：张宜苏 / 张鹏程
# 导演：邵攀
# 豆瓣评分：8.5
# 时长：149分钟
# 上映地区：中国大陆
# ===================================================
# 片名：叶问外传：张天志 葉問外傳：張天志
# 主演：张晋 / 戴夫·巴蒂斯塔 / 柳岩
# 导演：袁和平
# 豆瓣评分：6.0
# 时长：107分钟
# 上映地区：中国大陆
# ===================================================
# 片名：密林诡影
# 主演：陈国良 / 肖红 / 吴美佳
# 导演：苗述
# 豆瓣评分：
# 时长：84分钟
# 上映地区：中国大陆
# ===================================================
# 这个位置没有海报
# ===================================================
# 这个位置没有海报
# ===================================================
